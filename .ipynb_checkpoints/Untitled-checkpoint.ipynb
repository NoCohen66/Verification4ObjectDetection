# %%
import pandas as pd

# %%
df = pd.read_csv("CGT_comp/0_iou_calculations.csv", index_col=0,  converters={"lb_box":pd.eval,  'ub_box':pd.eval,'IoU_extension':pd.eval})

# %%
df['IoU_extension_min'] = df['IoU_extension'].apply(lambda x: x[0])

# %%
df = df[['eps', 'perturbation', 'lb_box', 'ub_box', 'IoU_extension_min']]

# %%
df[(df["perturbation"] == "brightness") | (df["perturbation"] == "CGT_brightness") | (df["perturbation"] == "whitenoise")]
# Out:
#        eps    perturbation                                lb_box  \
# 0      0.0      whitenoise   [32.952217, 0, 59.966034, 25.80181]
# 2      0.0      brightness   [32.952217, 0, 59.966034, 25.80181]
# 4        -  CGT_brightness   [32.952217, 0, 59.966038, 25.80181]
# 5   0.0001      whitenoise   [32.67482, 0, 59.577385, 25.601044]
# 7   0.0001      brightness  [32.707336, 0, 59.632694, 25.631872]
# 9        0  CGT_brightness   [31.646738, 0, 57.793373, 24.28714]
# 10  0.0002      whitenoise   [32.36612, 0, 59.164635, 25.389101]
# 12  0.0002      brightness   [32.43131, 0, 59.275414, 25.450832]
# 14       .  CGT_brightness   [30.332184, 0, 55.622135, 22.78185]
#
#                                   ub_box  IoU_extension_min
# 0    [32.952217, 0, 59.966034, 25.80181]           0.826069
# 2    [32.952217, 0, 59.966034, 25.80181]           0.826069
# 4    [32.952217, 0, 59.966038, 25.80181]           0.826069
# 5    [33.85014, 0, 61.538506, 26.668604]           0.800571
# 7     [33.841316, 0, 61.52336, 26.65977]           0.804047
# 9     [34.220486, 0, 62.0896, 27.306053]           0.687000
# 10   [34.886322, 0, 63.395523, 27.76165]           0.773980
# 12  [34.869137, 0, 63.365906, 27.743792]           0.780752
# 14    [35.52211, 0, 64.290924, 28.88103]           0.567791

# %%
df.perturbation
# Out:
# 0          whitenoise
# 1     whitenoise_xLxU
# 2          brightness
# 3            contrast
# 4      CGT_brightness
# 5          whitenoise
# 6     whitenoise_xLxU
# 7          brightness
# 8            contrast
# 9      CGT_brightness
# 10         whitenoise
# 11    whitenoise_xLxU
# 12         brightness
# 13           contrast
# 14     CGT_brightness
# Name: perturbation, dtype: object

# %%
df[(df["perturbation"] == "whitenoise_xLxU") | (df["perturbation"] == "CGT_brightness") | (df["perturbation"] == "whitenoise")]
# Out:
#        eps     perturbation                                lb_box  \
# 0      0.0       whitenoise   [32.952217, 0, 59.966034, 25.80181]
# 1        -  whitenoise_xLxU   [32.952217, 0, 59.966034, 25.80181]
# 4        -   CGT_brightness   [32.952217, 0, 59.966038, 25.80181]
# 5   0.0001       whitenoise   [32.67482, 0, 59.577385, 25.601044]
# 6        0  whitenoise_xLxU  [32.787422, 0, 59.721287, 25.673454]
# 9        0   CGT_brightness   [31.646738, 0, 57.793373, 24.28714]
# 10  0.0002       whitenoise   [32.36612, 0, 59.164635, 25.389101]
# 11       .  whitenoise_xLxU   [32.617798, 0, 59.47109, 25.542301]
# 14       .   CGT_brightness   [30.332184, 0, 55.622135, 22.78185]
#
#                                   ub_box  IoU_extension_min
# 0    [32.952217, 0, 59.966034, 25.80181]           0.826069
# 1    [32.952217, 0, 59.966034, 25.80181]           0.826069
# 4    [32.952217, 0, 59.966038, 25.80181]           0.826069
# 5    [33.85014, 0, 61.538506, 26.668604]           0.800571
# 6   [33.359333, 0, 60.669323, 26.179844]           0.810120
# 9     [34.220486, 0, 62.0896, 27.306053]           0.687000
# 10   [34.886322, 0, 63.395523, 27.76165]           0.773980
# 11   [33.78806, 0, 61.426495, 26.608047]           0.794076
# 14    [35.52211, 0, 64.290924, 28.88103]           0.567791
